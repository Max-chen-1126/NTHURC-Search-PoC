# %%
from typing import List
from dotenv import load_dotenv
from google.api_core.client_options import ClientOptions
from google.cloud import discoveryengine_v1 as discoveryengine

# TODO(developer): Uncomment these variables before running the sample.
project_id = "nthurc-aisearch-202406"
location = "global"                    # Values: "global", "us", "eu"
data_store_id = "pdf-data-search_1718003912950"
search_queries = ["我想申請社宅", "三峽國光"]
load_dotenv()


def multi_turn_search_sample(
    project_id: str,
    location: str,
    data_store_id: str,
    search_queries: List[str],
) -> List[discoveryengine.ConverseConversationResponse]:
    #  For more information, refer to:
    # https://cloud.google.com/generative-ai-app-builder/docs/locations#specify_a_multi-region_for_your_data_store
    client_options = (
        ClientOptions(
            api_endpoint=f"{location}-discoveryengine.googleapis.com")
        if location != "global"
        else None
    )

    # Create a client
    client = discoveryengine.ConversationalSearchServiceClient(
        client_options=client_options
    )

    # Initialize Multi-Turn Session
    conversation = client.create_conversation(
        # The full resource name of the data store
        # e.g. projects/{project_id}/locations/{location}/dataStores/{data_store_id}
        parent=client.data_store_path(
            project=project_id, location=location, data_store=data_store_id
        ),
        conversation=discoveryengine.Conversation(),
    )

    for search_query in search_queries:
        # Add new message to session
        request = discoveryengine.ConverseConversationRequest(
            name=conversation.name,
            query=discoveryengine.TextInput(input=search_query),
            serving_config=client.serving_config_path(
                project=project_id,
                location=location,
                data_store=data_store_id,
                serving_config="default_config",
            ),
            # Options for the returned summary
            summary_spec=discoveryengine.SearchRequest.ContentSearchSpec.SummarySpec(
                # Number of results to include in summary
                summary_result_count=3,
                include_citations=True,
            ),
        )
        response = client.converse_conversation(request)

        print(f"Reply: {response.reply.summary.summary_text}\n")

        for i, result in enumerate(response.search_results, 1):
            result_data = result.document.derived_struct_data
            print(result_data)
            print(f"[{i}]")
            print(f"Link: {result_data['link']}")
            print(f"First Snippet: {result_data['snippets'][0]['snippet']}")
            print(
                "First Extractive Answer: \n"
                f"\tPage: {result_data['extractive_answers'][0]['pageNumber']}\n"
                f"\tContent: {result_data['extractive_answers'][0]['content']}\n\n"
            )
        print("\n\n")

        return response


response = multi_turn_search_sample(
    project_id, location, data_store_id, search_queries)
# Out:
# Reply: 要申请新北市青年社会住宅，您需要满足一些条件，例如年满18岁或已婚未满18岁，在新北市设籍、就学或就业，且家庭成员在台北市、新北市、桃园市和基隆市均无自有住宅 [3]。此外，家庭成员的收入也需要符合当年度的公告标准 [3]。您需要准备一些文件，例如全户最新电子户籍謄本正本或全户户口名簿影本，以及最近一年的财产归属资料清单正本 [1]。您可以在新北市住房及都市更新中心网站上在线申请，也可以到土城员和青年社会住宅管理中心现场申请 [2, 3]。
#
#
# <proto.marshal.collections.maps.MapComposite object at 0x10abcf050>
# [1]
# Link: gs://nthurc-aisearch-poc-data/PDF_PoC/申請須知(上).pdf
# First Snippet: 本次開放<b>申請</b>「土城大安、土城永和、板橋江翠、土城明德 2 號、五股成州、新店央北及三峽國 光」等 7 處<b>社宅</b>，<b>申請</b>人應就所<b>申請</b>承租<b>社宅</b>，分別填寫<b>申請</b>書，並依<b>申請</b>身分&nbsp;...
# First Extractive Answer:
# 	Page: 11
# 	Content: 11 (三)提前終止租約事由： 承租人如有轉租、非法使用青年社會住宅、積欠達2 個月租金總額並經催告後仍不悉數繳清或構成其他終止租約之事由者，本中心得提前終止租約，且承租人應無條件將房屋回復原狀交還予本中心。 (四)違規扣點機制： 承租戶(包含共同居住之家屬或第三人)如有違反「出租住宅住戶管理規則」之情事，本中心將依「出租住宅住戶管理規則」第九條違規處分之規定執行扣點處分，扣點累計達15 點，承租人日後不得<b>申請</b>續租新北青年社會住宅(含本案)，累計達30 點者，本中心將立即提前終止租約。 (五)不得<b>申請</b>承租之限制： 1.承租新北市社會住宅如被扣點累計達30 點者，自扣點達30 點之日起3 年內不得<b>申請</b>承租新北市青年社會住宅或其他公共住宅。 2.租期屆滿或終止租賃契約，承租戶如未依規定辦理房屋返還，承租戶及其同居人或其允許為房屋使用之第三人自承租戶完成返還房屋之日起3 年內，不得再<b>申請</b>承租新北市青年社會住宅或其他公共住宅。但如未於終止租約並完成返還房屋者，於終止租約至完成返還房屋之期間，亦不得再<b>申請</b>承租新北市青年社會住宅或其他公共住宅。 3.租期屆滿時如有積欠應負擔之租金、水費、電費、瓦斯費、管理費、遺留物品處理費、公證費、修繕費或損害賠償等費用，於未完成清償前不得再<b>申請</b>承租新北市青年社會住宅或其他公共住宅。 (六)本案自113 年2 月29 日公告日起至113 年3 月11 日止，本中心仍保有公告及相關隨到隨辦作業之修改及解釋權限。 (七)其他： 合格<b>申請</b>人經通知選屋並完成簽約手續後經相關單位抽查，若發現其資格不符者，租賃契約自始無效，承租人應無條件於本中心通知日30 日內清空房屋點交設備予本中心。 申租洽詢專線： ( 0 2 ) 2 6 7 1 - 0 6 2 2 、 ( 0 2 ) 2 9 6 7 - 2 9 4 8 新北市住宅及都市更新中心，電話：（02）2957-1999 分機116 中華民國1 1 3 年2 月2 9 日

# %%
# code heavily inspired by https://cloud.google.com/generative-ai-app-builder/docs/multi-turn-search#genappbuilder_multi_turn_search-python
from typing import List
from google.api_core.client_options import ClientOptions
from google.cloud import discoveryengine_v1 as discoveryengine
import os
import argparse  # Import the argparse module


def multi_turn_search_sample(
    project_id: str,
    location: str,
    data_store_id: str,
    search_queries: List[str],
    conversation_id: str = None,
) -> List[discoveryengine.ConverseConversationResponse]:
    client_options = (
        ClientOptions(
            api_endpoint=f"{location}-discoveryengine.googleapis.com")
        if location != "global"
        else None
    )

    # Create a client
    client = discoveryengine.ConversationalSearchServiceClient(
        client_options=client_options
    )

    if conversation_id:
        conversation_name = client.conversation_path(
            project=project_id, location=location, data_store=data_store_id, conversation=conversation_id)
    else:
        conversation = client.create_conversation(
            parent=client.data_store_path(
                project=project_id, location=location, data_store=data_store_id),
            conversation=discoveryengine.Conversation(),
        )
        conversation_name = conversation.name
        print(f"Conversation ID: {conversation.name.split('/')[-1]}")

    for search_query in search_queries:
        request = discoveryengine.ConverseConversationRequest(
            name=conversation_name,
            query=discoveryengine.TextInput(input=search_query),
            serving_config=client.serving_config_path(
                project=project_id,
                location=location,
                data_store=data_store_id,
                serving_config="default_config",
            ),
            summary_spec=discoveryengine.SearchRequest.ContentSearchSpec.SummarySpec(
                summary_result_count=3,
                include_citations=True,
            ),
        )
        response = client.converse_conversation(request)
        print(response)


search_queries = ["戶口名簿是什麼？"]
multi_turn_search_sample(project_id, location, data_store_id,
                         search_queries, "8354159113724969335")
# Out:
# reply {
#   summary {
#     summary_text: "戶口名簿是用来证明您和您的家庭成员的户籍关系的官方文件 [1, 2, 3]。 您可以选择提供全户最新电子户籍謄本正本或户口名簿影本 [1, 2, 3]。 申请人需要在申请期限内备妥相关文件，并于收件时间亲至土城员和青年社会住宅管理中心完成送件 [2]。 申请日期应为民国113年2月29日(含)以后 [1]。 此外，您还需要提供新北市设籍或就学、就業證明正本 [1]。 \n"
#     summary_with_metadata {
#       summary: "戶口名簿是用来证明您和您的家庭成员的户籍关系的官方文件。 您可以选择提供全户最新电子户籍謄本正本或户口名簿影本。 申请人需要在申请期限内备妥相关文件，并于收件时间亲至土城员和青年社会住宅管理中心完成送件。 申请日期应为民国113年2月29日(含)以后。 此外，您还需要提供新北市设籍或就学、就業證明正本。 \n"
#       citation_metadata {
#         citations {
#           end_index: 84
#           sources {
#           }
#           sources {
#             reference_index: 1
#           }
#           sources {
#             reference_index: 2
#           }
#         }
#         citations {
#           start_index: 85
#           end_index: 166
#           sources {
#           }
#           sources {
#             reference_index: 1
#           }
#           sources {
#             reference_index: 2
#           }
#         }
#         citations {
#           start_index: 167
#           end_index: 302
#           sources {
#             reference_index: 1
#           }
#         }
#         citations {
#           start_index: 303
#           end_index: 356
#           sources {
#           }
#         }
#         citations {
#           start_index: 357
#           end_index: 432
#           sources {
#           }
#         }
#       }
#       references {
#         title: "<4D6963726F736F667420576F7264202D20313133A67EABD7B2C431A6B8C048A8ECC048BFEC28A467ABB0A46AA677A142A467ABB0A5C3A94DA142A4ADAAD1A6A8A67BA142B773A9B1A5A1A55FA4CEA454AE6CB0EAA5FA292DA5D3BDD0B6B7AABE>"
#         document: "projects/362021287114/locations/global/collections/default_collection/dataStores/pdf-data-search_1718003912950/branches/0/documents/2c19656a5ab29bcff2059bb0b65108b9"
#         uri: "gs://nthurc-aisearch-poc-data/PDF_PoC/申請須知.pdf"
#       }
#       references {
#         title: "網站常見問題集"
#         document: "projects/362021287114/locations/global/collections/default_collection/dataStores/pdf-data-search_1718003912950/branches/0/documents/2d6dd704e20fad66e2d83193a2a8e1e4"
#         uri: "gs://nthurc-aisearch-poc-data/PDF_PoC/網站常見問題集.pdf"
#       }
#       references {
#         title: "申請須知 (下)"
#         document: "projects/362021287114/locations/global/collections/default_collection/dataStores/pdf-data-search_1718003912950/branches/0/documents/d94d4fa42822476bdcbb34c4eb165508"
#         uri: "gs://nthurc-aisearch-poc-data/PDF_PoC/申請須知 (下).pdf"
#       }
#     }
#   }
# }
# conversation {
#   name: "projects/362021287114/locations/global/collections/default_collection/dataStores/pdf-data-search_1718003912950/conversations/8354159113724969335"
#   state: IN_PROGRESS
#   user_pseudo_id: "8354159113724969335"
#   messages {
#     user_input {
#       input: "我想申請社宅"
#     }
#   }
#   messages {
#     reply {
#       summary {
#         summary_text: "要申请新北市青年社会住宅，您需要满足一些条件，例如年满18岁或已婚未满18岁，在新北市设籍、就学或就业，且家庭成员在台北市、新北市、桃园市和基隆市均无自有住宅 [3]。 此外，家庭成员的收入也需要符合当年度的公告标准 [3]。 申请人需要准备相关文件，例如全户最新电子户籍謄本正本或户口名簿影本，以及最近一年的财产归属资料清单正本 [1]。 申请期限为民国113年3月12日至4月11日，您可以选择现场或线上申请 [2]。 申请人需要在申请期限内备妥相关文件，并于收件时间亲至土城员和青年社会住宅管理中心完成送件 [2]。 \n"
#         summary_with_metadata {
#           summary: "要申请新北市青年社会住宅，您需要满足一些条件，例如年满18岁或已婚未满18岁，在新北市设籍、就学或就业，且家庭成员在台北市、新北市、桃园市和基隆市均无自有住宅。 此外，家庭成员的收入也需要符合当年度的公告标准。 申请人需要准备相关文件，例如全户最新电子户籍謄本正本或户口名簿影本，以及最近一年的财产归属资料清单正本。 申请期限为民国113年3月12日至4月11日，您可以选择现场或线上申请。 申请人需要在申请期限内备妥相关文件，并于收件时间亲至土城员和青年社会住宅管理中心完成送件。 \n"
#           citation_metadata {
#             citations {
#               end_index: 232
#               sources {
#                 reference_index: 2
#               }
#             }
#             citations {
#               start_index: 233
#               end_index: 305
#               sources {
#                 reference_index: 2
#               }
#             }
#             citations {
#               start_index: 306
#               end_index: 462
#               sources {
#               }
#             }
#             citations {
#               start_index: 463
#               end_index: 553
#               sources {
#                 reference_index: 1
#               }
#             }
#             citations {
#               start_index: 554
#               end_index: 689
#               sources {
#                 reference_index: 1
#               }
#             }
#           }
#           references {
#             title: "申請須知(上)"
#             document: "projects/362021287114/locations/global/collections/default_collection/dataStores/pdf-data-search_1718003912950/branches/0/documents/2e4aef8099a2d1ef0b056c3fd076bedd"
#             uri: "gs://nthurc-aisearch-poc-data/PDF_PoC/申請須知(上).pdf"
#           }
#           references {
#             title: "申請須知 (下)"
#             document: "projects/362021287114/locations/global/collections/default_collection/dataStores/pdf-data-search_1718003912950/branches/0/documents/d94d4fa42822476bdcbb34c4eb165508"
#             uri: "gs://nthurc-aisearch-poc-data/PDF_PoC/申請須知 (下).pdf"
#           }
#           references {
#             title: "網站常見問題集"
#             document: "projects/362021287114/locations/global/collections/default_collection/dataStores/pdf-data-search_1718003912950/branches/0/documents/2d6dd704e20fad66e2d83193a2a8e1e4"
#             uri: "gs://nthurc-aisearch-poc-data/PDF_PoC/網站常見問題集.pdf"
#           }
#         }
#       }
#     }
#   }
#   messages {
#     user_input {
#       input: "三峽國光"
#     }
#   }
#   messages {
#     reply {
#       summary {
#         summary_text: "三峽國光社宅的地址是新北市三峽區三樹一街2號 [1]。 租金分為四個等級，依家庭所得階層而定 [1]。 套房的月租金從3400元到8300元不等 [1]。 申請資格需要符合優先戶或一般戶青年族群的條件 [1]。 此外，您需要準備相關文件，例如全戶最新電子戶籍謄本正本或戶口名簿影本，以及最近一年的財產歸屬資料清單正本 [1]。 \n"
#         summary_with_metadata {
#           summary: "三峽國光社宅的地址是新北市三峽區三樹一街2號。 租金分為四個等級，依家庭所得階層而定。 套房的月租金從3400元到8300元不等。 申請資格需要符合優先戶或一般戶青年族群的條件。 此外，您需要準備相關文件，例如全戶最新電子戶籍謄本正本或戶口名簿影本，以及最近一年的財產歸屬資料清單正本。 \n"
#           citation_metadata {
#             citations {
#               end_index: 67
#               sources {
#               }
#             }
#             citations {
#               start_index: 68
#               end_index: 125
#               sources {
#               }
#             }
#             citations {
#               start_index: 126
#               end_index: 173
#               sources {
#               }
#             }
#             citations {
#               start_index: 174
#               end_index: 243
#               sources {
#               }
#             }
#             citations {
#               start_index: 244
#               end_index: 403
#               sources {
#               }
#             }
#           }
#           references {
#             title: "申請須知(上)"
#             document: "projects/362021287114/locations/global/collections/default_collection/dataStores/pdf-data-search_1718003912950/branches/0/documents/2e4aef8099a2d1ef0b056c3fd076bedd"
#             uri: "gs://nthurc-aisearch-poc-data/PDF_PoC/申請須知(上).pdf"
#           }
#           references {
#             title: "<4D6963726F736F667420576F7264202D20313133A67EABD7B2C431A6B8C048A8ECC048BFEC28A467ABB0A46AA677A142A467ABB0A5C3A94DA142A4ADAAD1A6A8A67BA142B773A9B1A5A1A55FA4CEA454AE6CB0EAA5FA292DA5D3BDD0B6B7AABE>"
#             document: "projects/362021287114/locations/global/collections/default_collection/dataStores/pdf-data-search_1718003912950/branches/0/documents/2c19656a5ab29bcff2059bb0b65108b9"
#             uri: "gs://nthurc-aisearch-poc-data/PDF_PoC/申請須知.pdf"
#           }
#           references {
#             title: "網站常見問題集"
#             document: "projects/362021287114/locations/global/collections/default_collection/dataStores/pdf-data-search_1718003912950/branches/0/documents/2d6dd704e20fad66e2d83193a2a8e1e4"
#             uri: "gs://nthurc-aisearch-poc-data/PDF_PoC/網站常見問題集.pdf"
#           }
#         }
#       }
#     }
#   }
#   messages {
#     user_input {
#       input: "我還還需要準備什麼?"
#     }
#   }
#   messages {
#     reply {
#       summary {
#         summary_text: "除了全戶最新電子戶籍謄本正本或戶口名簿影本，以及最近一年的財產歸屬資料清單正本之外 [1]，您还需要准备申请人及家庭成员自财政部国税局查调的最近一年度的综合所得税各類所得資料清單正本 [1]。 申请日期应为民国113年2月29日(含)以后 [1]。 此外，您还需要提供新北市设籍或就学、就業證明正本 [1]。 如果您是申请土城大安、土城永和、板橋江翠或土城明德2号社宅，还需要提供睦邻户资格证明 [1]。 \n"
#         summary_with_metadata {
#           summary: "除了全戶最新電子戶籍謄本正本或戶口名簿影本，以及最近一年的財產歸屬資料清單正本之外，您还需要准备申请人及家庭成员自财政部国税局查调的最近一年度的综合所得税各類所得資料清單正本。 申请日期应为民国113年2月29日(含)以后。 此外，您还需要提供新北市设籍或就学、就業證明正本。 如果您是申请土城大安、土城永和、板橋江翠或土城明德2号社宅，还需要提供睦邻户资格证明。 \n"
#           citation_metadata {
#             citations {
#               end_index: 264
#               sources {
#               }
#             }
#             citations {
#               start_index: 265
#               end_index: 318
#               sources {
#               }
#             }
#             citations {
#               start_index: 319
#               end_index: 394
#               sources {
#               }
#             }
#             citations {
#               start_index: 395
#               end_index: 522
#               sources {
#               }
#             }
#           }
#           references {
#             title: "申請須知(上)"
#             document: "projects/362021287114/locations/global/collections/default_collection/dataStores/pdf-data-search_1718003912950/branches/0/documents/2e4aef8099a2d1ef0b056c3fd076bedd"
#             uri: "gs://nthurc-aisearch-poc-data/PDF_PoC/申請須知(上).pdf"
#           }
#           references {
#             title: "申請須知 (下)"
#             document: "projects/362021287114/locations/global/collections/default_collection/dataStores/pdf-data-search_1718003912950/branches/0/documents/d94d4fa42822476bdcbb34c4eb165508"
#             uri: "gs://nthurc-aisearch-poc-data/PDF_PoC/申請須知 (下).pdf"
#           }
#           references {
#             title: "網站常見問題集"
#             document: "projects/362021287114/locations/global/collections/default_collection/dataStores/pdf-data-search_1718003912950/branches/0/documents/2d6dd704e20fad66e2d83193a2a8e1e4"
#             uri: "gs://nthurc-aisearch-poc-data/PDF_PoC/網站常見問題集.pdf"
#           }
#         }
#       }
#     }
#   }
#   messages {
#     user_input {
#       input: "戶口名簿是什麼？"
#     }
#   }
#   messages {
#     reply {
#       summary {
#         summary_text: "戶口名簿是用来证明您和您的家庭成员的户籍关系的官方文件 [1, 2, 3]。 您可以选择提供全户最新电子户籍謄本正本或户口名簿影本 [1, 2, 3]。 申请人需要在申请期限内备妥相关文件，并于收件时间亲至土城员和青年社会住宅管理中心完成送件 [2]。 申请日期应为民国113年2月29日(含)以后 [1]。 此外，您还需要提供新北市设籍或就学、就業證明正本 [1]。 \n"
#         summary_with_metadata {
#           summary: "戶口名簿是用来证明您和您的家庭成员的户籍关系的官方文件。 您可以选择提供全户最新电子户籍謄本正本或户口名簿影本。 申请人需要在申请期限内备妥相关文件，并于收件时间亲至土城员和青年社会住宅管理中心完成送件。 申请日期应为民国113年2月29日(含)以后。 此外，您还需要提供新北市设籍或就学、就業證明正本。 \n"
#           citation_metadata {
#             citations {
#               end_index: 84
#               sources {
#               }
#               sources {
#                 reference_index: 1
#               }
#               sources {
#                 reference_index: 2
#               }
#             }
#             citations {
#               start_index: 85
#               end_index: 166
#               sources {
#               }
#               sources {
#                 reference_index: 1
#               }
#               sources {
#                 reference_index: 2
#               }
#             }
#             citations {
#               start_index: 167
#               end_index: 302
#               sources {
#                 reference_index: 1
#               }
#             }
#             citations {
#               start_index: 303
#               end_index: 356
#               sources {
#               }
#             }
#             citations {
#               start_index: 357
#               end_index: 432
#               sources {
#               }
#             }
#           }
#           references {
#             title: "<4D6963726F736F667420576F7264202D20313133A67EABD7B2C431A6B8C048A8ECC048BFEC28A467ABB0A46AA677A142A467ABB0A5C3A94DA142A4ADAAD1A6A8A67BA142B773A9B1A5A1A55FA4CEA454AE6CB0EAA5FA292DA5D3BDD0B6B7AABE>"
#             document: "projects/362021287114/locations/global/collections/default_collection/dataStores/pdf-data-search_1718003912950/branches/0/documents/2c19656a5ab29bcff2059bb0b65108b9"
#             uri: "gs://nthurc-aisearch-poc-data/PDF_PoC/申請須知.pdf"
#           }
#           references {
#             title: "網站常見問題集"
#             document: "projects/362021287114/locations/global/collections/default_collection/dataStores/pdf-data-search_1718003912950/branches/0/documents/2d6dd704e20fad66e2d83193a2a8e1e4"
#             uri: "gs://nthurc-aisearch-poc-data/PDF_PoC/網站常見問題集.pdf"
#           }
#           references {
#             title: "申請須知 (下)"
#             document: "projects/362021287114/locations/global/collections/default_collection/dataStores/pdf-data-search_1718003912950/branches/0/documents/d94d4fa42822476bdcbb34c4eb165508"
#             uri: "gs://nthurc-aisearch-poc-data/PDF_PoC/申請須知 (下).pdf"
#           }
#         }
#       }
#     }
#   }
#   start_time {
#     seconds: 1721627333
#     nanos: 386847000
#   }
# }
# search_results {
#   id: "2c19656a5ab29bcff2059bb0b65108b9"
#   document {
#     name: "projects/362021287114/locations/global/collections/default_collection/dataStores/pdf-data-search_1718003912950/branches/0/documents/2c19656a5ab29bcff2059bb0b65108b9"
#     id: "2c19656a5ab29bcff2059bb0b65108b9"
#     derived_struct_data {
#       fields {
#         key: "title"
#         value {
#           string_value: "<4D6963726F736F667420576F7264202D20313133A67EABD7B2C431A6B8C048A8ECC048BFEC28A467ABB0A46AA677A142A467ABB0A5C3A94DA142A4ADAAD1A6A8A67BA142B773A9B1A5A1A55FA4CEA454AE6CB0EAA5FA292DA5D3BDD0B6B7AABE>"
#         }
#       }
#       fields {
#         key: "snippets"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "snippet"
#                   value {
#                     string_value: "子女與申請人不同戶籍 者須檢附子女之<b>戶口名簿</b> 影本、電子戶籍謄本或國 民身分證影本。 3人以上 +6 於安置教養機構或 寄養家庭結束安置 無法返家，未滿25 歲 +2 社政&nbsp;..."
#                   }
#                 }
#                 fields {
#                   key: "snippet_status"
#                   value {
#                     string_value: "SUCCESS"
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "link"
#         value {
#           string_value: "gs://nthurc-aisearch-poc-data/PDF_PoC/申請須知.pdf"
#         }
#       }
#       fields {
#         key: "extractive_answers"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "pageNumber"
#                   value {
#                     string_value: "12"
#                   }
#                 }
#                 fields {
#                   key: "content"
#                   value {
#                     string_value: "12 【附表一】優先戶評點表項目內容權重備註低收入戶列冊之低收入戶+4 檢具當年度低收入戶證明影版。 中低收入戶列冊之中低收入戶+2 檢具當年度中低收入戶證明影版。 特殊境遇家庭符合特殊境遇家庭扶助條例所定各項家庭扶助+6 檢具當年度特殊境遇家庭扶助公文影版。 育有未成年子女2人+4 1.申請人育有未滿18歲之子女，該子女須為申請人所生且其監護權為申請人（申請人單獨監護或共同監護皆可） 2.子女與申請人不同戶籍者須檢附子女之<b>戶口名簿</b>影本、電子戶籍謄本或國民身分證影本。 3人以上+6 於安置教養機構或寄養家庭結束安置無法返家，未滿25 歲+2 社政主管機關出具之證明影
#                   }
#                 }
#               }
#             }
#             values {
#               struct_value {
#                 fields {
#                   key: "pageNumber"
#                   value {
#                     string_value: "8"
#                   }
#                 }
#                 fields {
#                   key: "content"
#                   value {
#                     string_value: "8 (二)核發收件編號: 親赴土城員和青年社會住宅管理中心現場申請者，經本中心人員當場審核後，如申請人之應備文件齊全並資格合格者，本中心即當場核發收件編號予該申請人。反之，如申請人之應備文件不齊全或資格不合格者，本中心將不核發收件編號予該申請人。 (三)電腦抽籤: 預訂於113 年6 月26 日(三)辦理電腦抽籤作業，抽籤結果將公告於「新北市住宅及都市更新中心」官網，供申請人查詢。 (四)合格申請人經抽籤後取得選屋序號列入各資格類別遞補名冊: 1. 合格申請人按其所屬之承租類別列入各該青年社會住宅優先戶族群、睦鄰戶族群、現職警消人員戶族群、一般戶青年族群、非青年族群遞補名冊最後一位遞補者排序之後。本案日後如有其他餘屋時，將依｢新北市住宅及都市更新中心青年社會住宅遞補作業原則」之規定，辦理其他餘屋之遞補承租作業。 2. 列入一般戶抽籤名單之合格申請人，依所符資格情形同時於睦鄰戶、現職警消人員戶及一般戶青年族群或非青年族群遞補名冊進行遞補；如完成遞補或放棄，則另一遞補名冊之序位立即失效。 3."
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
# search_results {
#   id: "2d6dd704e20fad66e2d83193a2a8e1e4"
#   document {
#     name: "projects/362021287114/locations/global/collections/default_collection/dataStores/pdf-data-search_1718003912950/branches/0/documents/2d6dd704e20fad66e2d83193a2a8e1e4"
#     id: "2d6dd704e20fad66e2d83193a2a8e1e4"
#     derived_struct_data {
#       fields {
#         key: "title"
#         value {
#           string_value: "網站常見問題集"
#         }
#       }
#       fields {
#         key: "snippets"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "snippet"
#                   value {
#                     string_value: "(4)尚無戶籍之 外籍配偶及直系親屬，以居留證等具公信力文件，證明與申請人居住於同一門牌者，得列為家庭人口 數。(5)同戶籍之直系親屬、夫妻（含分戶），僅得由其中&nbsp;..."
#                   }
#                 }
#                 fields {
#                   key: "snippet_status"
#                   value {
#                     string_value: "SUCCESS"
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "link"
#         value {
#           string_value: "gs://nthurc-aisearch-poc-data/PDF_PoC/網站常見問題集.pdf"
#         }
#       }
#       fields {
#         key: "extractive_answers"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "pageNumber"
#                   value {
#                     string_value: "4"
#                   }
#                 }
#                 fields {
#                   key: "content"
#                   value {
#                     string_value: "Q and A Q: 04 何謂家庭成員？家庭成員可以分開同時提出申請嗎？如何計算人口數？ A: 1. 家庭成員：指申請人及其配偶（含分戶）、申請人戶籍內直系親屬（即父母、子女或祖父母）。2. 每一家庭成員以申請一戶為限。3. 人口數計算：(1)申請2 房者，申請人之家庭人口數應至少2 人以上，依申請時檢附之戶籍資料，審查家庭成員之人口總數，是否符合各房型家庭成員人口數規定。(2)申請3 房者，申請人之家庭人口數應至少3 人以上，依申請時檢附之戶籍資料，審查家庭成員之人口總數，是否符合各房型家庭成員人口數規定。(3)申請人或其配偶持醫院證明正本或媽媽手冊影本能證明已懷孕者，胎兒視為1口。(4)尚無戶籍之外籍配偶及直系親屬，以居留證等具公信力文件，證明與申請人居住於同一門牌者，得列為家庭人口數。(5)同戶籍之直系親屬、夫妻（含分戶），僅得由其中一人為申請人，重複申請時，由本局向申請人確認放棄者，逾期未能確認，申請在後者視為不合格。(6)同戶籍之旁系親屬各自申請者，戶籍內直系親屬不得重複計入家庭人口數，重複計入時，由本局向申請人確認，逾期未能確認，該人口數計入申請在前者。 Page 4."
#                   }
#                 }
#               }
#             }
#             values {
#               struct_value {
#                 fields {
#                   key: "pageNumber"
#                   value {
#                     string_value: "6"
#                   }
#                 }
#                 fields {
#                   key: "content"
#                   value {
#                     string_value: "Q and A Q: 06 申請人之子女未成年，是否仍需檢附其財產歸屬資料清單及綜合所得稅各類所得資料清單？ A: <b>是</b>，申請人須檢附申請人及其配偶、申請人戶籍內直系親屬最近一年之財產歸屬資料清單及綜合所得稅各類所得資料清單；若子女為未滿1歲者，則只需檢附其財產歸屬資料清單。 Page 6."
#                   }
#                 }
#               }
#             }
#             values {
#               struct_value {
#                 fields {
#                   key: "pageNumber"
#                   value {
#                     string_value: "3"
#                   }
#                 }
#                 fields {
#                   key: "content"
#                   value {
#                     string_value: "Q and A Q: 03 特殊身分或情形的定義？ A: 依據住宅法第4 條第1 項規定：特殊情形或身分，指下列規定之一者：1.低收入戶或中低收入戶。2.特殊境遇家庭。3.育有未成年子女2人以上（申請人或配偶於公告日前已懷孕者，得計入）4.於安置教養機構或寄養家庭結束安置無法返家，未滿25 歲。5.65 歲以上之老人。6.受家庭暴力或性侵害之受害者及其子女。7.身心障礙者。8.感染人類免疫缺乏病毒者或罹患後天免疫缺乏症候群者。9.原住民。10.災民。11.遊民。12.因懷孕或生育而遭遇困境之未成年人。 Page 3."
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
# search_results {
#   id: "d94d4fa42822476bdcbb34c4eb165508"
#   document {
#     name: "projects/362021287114/locations/global/collections/default_collection/dataStores/pdf-data-search_1718003912950/branches/0/documents/d94d4fa42822476bdcbb34c4eb165508"
#     id: "d94d4fa42822476bdcbb34c4eb165508"
#     derived_struct_data {
#       fields {
#         key: "title"
#         value {
#           string_value: "申請須知 (下)"
#         }
#       }
#       fields {
#         key: "snippets"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "snippet"
#                   value {
#                     string_value: "... 戶最新電子戶籍謄本正本或<b>戶口名簿</b>影 本。 10.災民：於申請表勾選相關欄位後，並應提供受災日起一年內經相關主管機關認定之文件影本。 11.遊民：於申請表勾選相關欄位&nbsp;..."
#                   }
#                 }
#                 fields {
#                   key: "snippet_status"
#                   value {
#                     string_value: "SUCCESS"
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "link"
#         value {
#           string_value: "gs://nthurc-aisearch-poc-data/PDF_PoC/申請須知 (下).pdf"
#         }
#       }
#       fields {
#         key: "extractive_answers"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "pageNumber"
#                   value {
#                     string_value: "1"
#                   }
#                 }
#                 fields {
#                   key: "content"
#                   value {
#                     string_value: "7 5.65 歲以上之老人：檢附【113 年2 月29 日(含)後】申請之全戶最新電子戶籍謄本正本或<b>戶口名簿</b>影本。 6.受家庭暴力或性侵害之受害者及其子女：受理申請截止前一年內曾經受家庭暴力或性侵害之有效證明影本(即保護令影本或確定判決書影本)。 7.身心障礙者：身心障礙手冊或證明影本。 8.感染人類免疫缺乏病毒者或罹患後天免疫缺乏症候群者：全國醫療服務卡影本（HIV）或檢附醫院、 衛生單位出具之證明文件正影本。 9.原住民：檢附【民國113 年2 月29 日(含)後】申請之全戶最新電子戶籍謄本正本或<b>戶口名簿</b>影本。 10.災民：於申請表勾選相關欄位後，並應提供受災日起一年內經相關主管機關認定之文件影本。 11.遊民：於申請表勾選相關欄位後由本中心通報主管機關認定。 12.因懷孕或生育而遭遇困境之未成年人：提供主管機關認定證明文件或經本中心通報主管機關認定。 四、申請期限：自民國113 年3 月12 日(二) 起至民國113 年4 月11 日(四)止。 (一)申請方式： 1.現場申請：申請人於申請期限內備妥相關文件，於收件時間親至土城員和青年社會住宅管理中心(新北市土城區莊園街155-1 號)填寫申請書並完成送件，逾期不受理。 2.線上申請：請至「新北市住宅及都市更新中心」（https://www.nthurc.org.tw）網站申請。 (二)收件及補件時間與地址： 1.日期：113 年3 月12 日(二)起至113 年4 月11 日(四)止（週一至週五：上午9:00~12:00，下午1:30~4:00) 2. ＊另開放週六113 年3 月23 日、113 年3 月30 日。 收件地址：土城員和青年社會住宅管理中心(新北市土城區莊園街155-1 號) (三)補正期限：申請人如有申請資料不齊全需補正，應依本中心通知之補正時間為準，並於收件時間親至土城員和青年社會住宅管理中心完成送件，逾期不受理。 五、電腦抽籤：民國113年6月26日(三) ，如有變動依本中心官網公告日期為準。 六、選屋與簽約公證：依看選屋序位，通知申請人辦理看選屋、簽約、公證及點交作業七、申辦流程： (一) ..."
#                   }
#                 }
#               }
#             }
#             values {
#               struct_value {
#                 fields {
#                   key: "pageNumber"
#                   value {
#                     string_value: "7"
#                   }
#                 }
#                 fields {
#                   key: "content"
#                   value {
#                     string_value: "13 【附表二】抽籤流程"
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
# search_results {
#   id: "2e4aef8099a2d1ef0b056c3fd076bedd"
#   document {
#     name: "projects/362021287114/locations/global/collections/default_collection/dataStores/pdf-data-search_1718003912950/branches/0/documents/2e4aef8099a2d1ef0b056c3fd076bedd"
#     id: "2e4aef8099a2d1ef0b056c3fd076bedd"
#     derived_struct_data {
#       fields {
#         key: "title"
#         value {
#           string_value: "申請須知(上)"
#         }
#       }
#       fields {
#         key: "snippets"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "snippet"
#                   value {
#                     string_value: "3 3. 各身分別分配房型如下表： 身分別 戶數 資格 套房 二房 三房 一般戶 24 睦鄰戶(5&nbsp;..."
#                   }
#                 }
#                 fields {
#                   key: "snippet_status"
#                   value {
#                     string_value: "SUCCESS"
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#       fields {
#         key: "link"
#         value {
#           string_value: "gs://nthurc-aisearch-poc-data/PDF_PoC/申請須知(上).pdf"
#         }
#       }
#       fields {
#         key: "extractive_answers"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "pageNumber"
#                   value {
#                     string_value: "3"
#                   }
#                 }
#                 fields {
#                   key: "content"
#                   value {
#                     string_value: "3 3. 各身分別分配房型如下表： 身分別戶數資格套房二房三房一般戶24 睦鄰戶(5%) 1 0 0 現職警消人員戶(5%) 1 0 0 屬18歲(含)以上未滿41歲(不含)之青年族群(72%) 8 3 6 屬41歲(含)以上之非青年族群(18%) 2 1 2 (五) 五股成州社宅： 1. 社宅地址：新北市五股區成泰路三段318 號。 2. 房型及月租金： 房型戶數坪數租金(含管理費)(元) 第1階第2階第3階第4階二房1 約29 坪10000 13700 18900 20900 4 約32 坪10600 14400 20100 22200 三房5 約36 坪12900 17800 22900 25400 汽車位5個3800元(非本次招租項目；承租人於完成房屋公證簽約後提出申請) 3. 各身分別分配房型如下表： 身分別戶數資格二房三房優先戶4 詳本申請須知第三條第七款(40%) 2 2 一般戶6 睦鄰戶(5%) 0 0 現職警消人員戶(5%) 0 0 屬18歲(含)以上未滿41歲(不含)之青年族群(40%) 2 2 屬41歲(含)以上之非青年族群(10%) 1 1 (六) 新店央北社宅： 1. 社宅地址：新北市新店區央北二路398 號。 2. 房型及月租金： 房型戶數坪數租金(含管理費)(元) 第1階第2階第3階第4階套房- 約11.5坪4200 6300 9200 10300 ※因應新店央北社宅「優先戶-套房型」遞補名單已用鑿，故僅開放具優先戶身分者提出申請。 3. 各身分別分配房型如下表： 身分別戶數資格套房優先戶- 詳本申請須知第三條第七款 -"
#                   }
#                 }
#               }
#             }
#             values {
#               struct_value {
#                 fields {
#                   key: "pageNumber"
#                   value {
#                     string_value: "2"
#                   }
#                 }
#                 fields {
#                   key: "content"
#                   value {
#                     string_value: "各身分別分配房型如下表： 身分別戶數資格套房二房三房優先戶21 詳本申請須知第三條第七款(40%) 4 15 2 一般戶31 睦鄰戶(5%) 1 2 0 現職警消人員戶(5%) 1 1 0 屬18歲(含)以上未滿41歲(不含)之青年族群(40%) 3 15 2 屬41歲(含)以上之非青年族群(10%) 1 4 1 (四) 土城明德2號社宅： 1. 社宅地址：新北市土城區學士路137 至159 號。 2. 房型及月租金： 房型戶數坪數租金(含管理費)(元) 第1階第2階第3階第4階套房4 約16 坪5500 7700 10900 12100 4 約19 坪6100 8600 13400 14900 4 約24 坪6900 9700 15500 18400 二房4 約25 坪9900 13900 16800 18600 三房8 約40 坪14100 19600 26200 29100 汽車位9個2900元、3000元(非本次招租項目；承租人於完成房屋公證簽約後提出申請)"
#                   }
#                 }
#               }
#             }
#             values {
#               struct_value {
#                 fields {
#                   key: "pageNumber"
#                   value {
#                     string_value: "1"
#                   }
#                 }
#                 fields {
#                   key: "content"
#                   value {
#                     string_value: "1 113 年度第1 次隨到隨辦土城大安、土城永和、板橋江翠、土城明德2 號、五股成州、新店央北及三峽國光等七處青年社會住宅申請須知(※限現場收件、線上申請；無郵寄申請) (本案公告日為113 年2 月29 日，本次受理應檢附之文件申請日須為公告日(含)以後申請) 一、 開放承租社宅之戶數、房型及租金： (一) 土城大安社宅： 1. 社宅地址：新北市土城區中央路89 巷150 號至170 號。 2. 房型、車位及月租金： 3. 各身分別分配房型如下表： 身分別戶數資格套房二房三房優先戶35 詳本申請須知第三條第七款(40%) 16 13 6 一般戶53 睦鄰戶(5%) 2 2 1 現職警消人員戶(5%) 2 2 1 屬18歲(含)以上未滿41歲(不含)之青年族群(40%) 16 13 6 屬41歲(含)以上之非青年族群(10%) 4 3 1 (二) 土城永和社宅： 1. 社宅地址：新北市土城區承天路4 巷2 號。 2. 房型及車位月租金： 房型戶數坪數租金(含管理費)(元) 第1階第2階第3階第4階套房11 約13.5 坪5000 7100 11300 12600 29 約15 坪5300 7500 12000 14000 二房5 約23 坪9300 13400 16500 18400 28 約25.5 坪9800 13900 17800 19800 三房1 約30 坪12900 18100 20400 22700 14 約34 坪13200 18900 22900 25500 汽車位43個2600元(非本次招租項目；承租人於完成房屋公證簽約後提出申請) 房型戶數坪數租金(含管理費)(元) 第1階第2階第3階第4階套房1 約12 坪4700 6700 9800 10900 28 約13.5 坪5000 7100 11300 12600 二房27 約23.5 坪8600 12900 16100 18100 三房10 約32 坪12100 18100 21200 23800 汽車位28個2600元(非本次招租項目；承租人於完成房屋公證簽約後提出申請)"
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }

# %%
import urllib
caption = response.reply.summary.summary_with_metadata.references

for i, reference in enumerate(caption, 1):

    print(f"[{i}] : [{reference.title}]({reference.uri})")

extractive_answers = []
caption = response.reply.summary.summary_with_metadata.references
for i, reference in enumerate(caption):
    if reference.uri.startswith('gs://'):
        link = 'https://storage.cloud.google.com/' + \
            urllib.parse.quote(reference.uri.replace(  # type: ignore
                'gs://', ''))  # type: ignore
    else:
        link = ""
    ref = f"[{i}] : [{reference.title}]({link})"
    extractive_answers.append(ref)
print(extractive_answers)
# Out:
# [1] : [申請須知(上)](gs://nthurc-aisearch-poc-data/PDF_PoC/申請須知(上).pdf)
# [2] : [申請須知 (下)](gs://nthurc-aisearch-poc-data/PDF_PoC/申請須知 (下).pdf)
# [3] : [網站常見問題集](gs://nthurc-aisearch-poc-data/PDF_PoC/網站常見問題集.pdf)
# ['[0] : [申請須知(上)](https://storage.cloud.google.com/nthurc-aisearch-poc-data/PDF_PoC/%E7%94%B3%E8%AB%8B%E9%A0%88%E7%9F%A5%28%E4%B8%8A%29.pdf)', '[1] : [申請須知 (下)](https://storage.cloud.google.com/nthurc-aisearch-poc-data/PDF_PoC/%E7%94%B3%E8%AB%8B%E9%A0%88%E7%9F%A5%20%28%E4%B8%8B%29.pdf)', '[2] : [網站常見問題集](https://storage.cloud.google.com/nthurc-aisearch-poc-data/PDF_PoC/%E7%B6%B2%E7%AB%99%E5%B8%B8%E8%A6%8B%E5%95%8F%E9%A1%8C%E9%9B%86.pdf)']
